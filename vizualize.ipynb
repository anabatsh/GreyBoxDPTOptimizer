# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd

# import warnings
# warnings.filterwarnings('ignore')

from solvers import *
from utils import show_results

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
! python ./main.py --problem Net --solver PROTES --kwargs '{"k_top": 2}' --save_dir 'results/0' --n_exp 2
# ! python ./utils.py
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:02<00:00,  1.08s/it]

# %%
# show_results('results/2', solvers=['PROTES'])

# %%
! python ./main.py --d 10 --n 2 --budget 12 --k_samples 5 --solver LLAMBO --kwargs '{"k_memory": 100}' --save_dir 'results/2' --n_exp 1
# Out:
# LLAMBO: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 347.24it/s]

# %%
show_results('results/2', solvers=['LLAMBO'])
