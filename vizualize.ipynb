# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd

# import warnings
# warnings.filterwarnings('ignore')

from solvers import *
from utils import *
from problems import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
! python ./main.py --problem Net --solver PSO --d 10 --n 2 --budget 10 --k_init 0 --k_samples 1 --save_dir "results/2" --n_exp 1

# %%
show_results('results/2', ['PSO'])

# %%
# ! python ./main.py --problem Net --solver BO --d 3 --n 2 --budget 25 --k_init 2 --save_dir "results/1" --n_exp 1
# ! python ./main.py --problem Net --solver PROTES --kwargs '{"k_top": 2}' --save_dir "results/1" --n_exp 2
# ! python ./main.py --problem Net --solver LLAMBO --kwargs '{"k_memory": 20}' --save_dir "results/0" --n_exp 1
# ! python ./utils.py --read_dir results/0 --problem Net

# %%
# show_results('results/1', ['BO'])

# %%
# ! python ./main.py --d 10 --n 2 --budget 12 --k_samples 5 --solver LLAMBO --kwargs '{"k_memory": 100}' --save_dir 'results/2' --n_exp 1

# %%
# show_results('results/2', solvers=['LLAMBO'])
