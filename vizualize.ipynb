# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd

import warnings
warnings.filterwarnings('ignore')

from solvers import *
from utils import show_results

# %%
# %load_ext autoreload
# %autoreload 2

# %%
! python ./main.py --d 10 --n 2 --budget 100 --k_samples 10 --solver PROTES --kwargs '{"k_top": 2}' --save_dir 'results/2' --n_exp 5
# Out:
# PROTES: 100%|█████████████████████████████████████| 5/5 [00:04<00:00,  1.10it/s]

# %%
show_results('results/2', solvers=['PROTES'])
